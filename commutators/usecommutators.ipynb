# %%
from commutators import *
# --- EXECUTION ---
N = 5  # Number of letters
K = 5  # Target weight

print(f"Building specific commutators for {N} letters up to weight {K}...")
result = count_specific_commutators(N, K)

# Output results
result.sort(key=lambda x: str(x))  # Sort just for pretty printing
print(f"\nFinal List (Weight {K}):")
for item in result:
    print(item)

# Math Verification
import math

expected = math.comb(N, K) * math.factorial(K - 1)
print(f"\nExpected Count: {expected}")
print(f"Actual Count:   {len(result)}")
# Out:
# Building specific commutators for 5 letters up to weight 5...
# Weight 2: Found 10 specific commutators.
# Weight 3: Found 20 specific commutators.
# Weight 4: Found 30 specific commutators.
# Weight 5: Found 24 specific commutators.
#
# Final List (Weight 5):
# [[[[x2, x1], x3], x4], x5]
# [[[[x3, x1], x2], x4], x5]
# [[[[x4, x1], x2], x3], x5]
# [[[[x5, x1], x2], x3], x4]
# [[[x2, x1], x3], [x5, x4]]
# [[[x2, x1], x4], [x5, x3]]
# [[[x2, x1], x5], [x4, x3]]
# [[[x3, x1], x2], [x5, x4]]
# [[[x3, x1], x4], [x5, x2]]
# [[[x3, x1], x5], [x4, x2]]
# [[[x3, x2], x4], [x5, x1]]
# [[[x3, x2], x5], [x4, x1]]
# [[[x4, x1], x2], [x5, x3]]
# [[[x4, x1], x3], [x5, x2]]
# [[[x4, x1], x5], [x3, x2]]
# [[[x4, x2], x3], [x5, x1]]
# [[[x4, x2], x5], [x3, x1]]
# [[[x4, x3], x5], [x2, x1]]
# [[[x5, x1], x2], [x4, x3]]
# [[[x5, x1], x3], [x4, x2]]
# [[[x5, x1], x4], [x3, x2]]
# [[[x5, x2], x3], [x4, x1]]
# [[[x5, x2], x4], [x3, x1]]
# [[[x5, x3], x4], [x2, x1]]
#
# Expected Count: 24
# ...
